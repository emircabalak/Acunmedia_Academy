# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import SGDClassifier

from matplotlib import pyplot as plt
import seaborn as sns

df = pd.read_csv("Admission_Predict.csv") # Veri setini yüklüyoruz

display(df.head())
display(df.info())
display(df.describe())
print(df.isnull().sum())
print(df.duplicated().sum())

# Veri seti hakkında genel bilgi ediniyoruz

df["Chance of Admit Binary"] = (df["Chance of Admit "] >= 0.75).astype(int) # 0.75 üzerinde olanlar 1, altinda olanlar 0
df["Chance of Admit Binary2"] = (df["Chance of Admit "] >= 0.70).astype(int) # 0.70 için
df["Chance of Admit Binary3"] = (df["Chance of Admit "] >= 0.80).astype(int) # 0.80 için
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.3 KB
# None
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# 25%      3.000000    8.170000    0.000000          0.640000
# 50%      3.500000    8.610000    1.000000          0.730000
# 75%      4.000000    9.062500    1.000000          0.830000
# max      5.000000    9.920000    1.000000          0.970000
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64
# 0

# %%
y = df["Chance of Admit Binary"]
X = df.drop(columns=["Serial No.", "Chance of Admit ","Chance of Admit Binary", "Chance of Admit Binary2", "Chance of Admit Binary3"])
# Bağımlı ve bağımsız değişkenleri ayırıyoruz.

scaler = StandardScaler() # StandardScaler kullanıyoruz.
scaled_data = scaler.fit_transform(X)
# Verileri standartlaştırıyoruz.

X_train, X_test, y_train, y_test = train_test_split(scaled_data, y, test_size=0.20, random_state=42) # Veri setini eğitim ve test setlerine ayırıyoruz.

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Modeli eğitim verisi ile eğitiyoruz.

y_pred = model.predict(X_test) # Test verisi ile tahmin yapıyoruz.

conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)
# Confusion matrix'i yazdırıyoruz.

accuracy = accuracy_score(y_test, y_pred)
print(f"Model Doğruluk Oranı: {accuracy:.2f}")
print("\nSınıflandırma Raporu:")
print(classification_report(y_test, y_pred))
# Sınıflandırma raporunu yazdırıyoruz.
# Out:
# Confusion Matrix:
# [[42  5]
#  [ 2 31]]
# Model Doğruluk Oranı: 0.91
#
# Sınıflandırma Raporu:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92        47
#            1       0.86      0.94      0.90        33
#
#     accuracy                           0.91        80
#    macro avg       0.91      0.92      0.91        80
# weighted avg       0.92      0.91      0.91        80

# %%
sgd_model = SGDClassifier(loss="log_loss", max_iter=1000, tol=1e-4, random_state=42, verbose=1) # SGDClassifier modelini oluşturuyoruz.

# Modeli SGDClassifier ile oluşturuyoruz.
sgd_model.fit(X_train, y_train.values.ravel())
# Out:
# -- Epoch 1
# Norm: 37.39, NNZs: 7, Bias: -3.463899, T: 320, Avg. loss: 3.858803
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 24.92, NNZs: 7, Bias: 5.580665, T: 640, Avg. loss: 2.754257
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 23.83, NNZs: 7, Bias: -6.752102, T: 960, Avg. loss: 2.259411
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 19.03, NNZs: 7, Bias: -1.539796, T: 1280, Avg. loss: 1.698976
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 14.42, NNZs: 7, Bias: 1.233616, T: 1600, Avg. loss: 1.657292
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 15.12, NNZs: 7, Bias: -2.388301, T: 1920, Avg. loss: 1.472138
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 11.64, NNZs: 7, Bias: -0.051688, T: 2240, Avg. loss: 1.477854
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 9.28, NNZs: 7, Bias: -8.337733, T: 2560, Avg. loss: 1.033451
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 9.15, NNZs: 7, Bias: -0.548798, T: 2880, Avg. loss: 1.106754
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 7.60, NNZs: 7, Bias: 0.641921, T: 3200, Avg. loss: 0.996433
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 7.55, NNZs: 7, Bias: 0.914578, T: 3520, Avg. loss: 1.030021
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 9.02, NNZs: 7, Bias: -1.449468, T: 3840, Avg. loss: 0.896819
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 7.54, NNZs: 7, Bias: -2.689560, T: 4160, Avg. loss: 0.707509
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 7.52, NNZs: 7, Bias: -0.375878, T: 4480, Avg. loss: 0.789470
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 8.94, NNZs: 7, Bias: 0.321067, T: 4800, Avg. loss: 0.725839
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 8.62, NNZs: 7, Bias: -2.039614, T: 5120, Avg. loss: 0.780381
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 5.93, NNZs: 7, Bias: -0.209725, T: 5440, Avg. loss: 0.704398
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 8.52, NNZs: 7, Bias: -1.484113, T: 5760, Avg. loss: 0.676522
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 6.77, NNZs: 7, Bias: -0.323238, T: 6080, Avg. loss: 0.612090
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 4.55, NNZs: 7, Bias: -0.500810, T: 6400, Avg. loss: 0.631947
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 5.58, NNZs: 7, Bias: 0.084890, T: 6720, Avg. loss: 0.525037
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 6.06, NNZs: 7, Bias: -2.792243, T: 7040, Avg. loss: 0.567911
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 4.43, NNZs: 7, Bias: -0.845619, T: 7360, Avg. loss: 0.579063
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 6.64, NNZs: 7, Bias: -0.569312, T: 7680, Avg. loss: 0.515645
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 6.46, NNZs: 7, Bias: -0.509838, T: 8000, Avg. loss: 0.539540
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 5.23, NNZs: 7, Bias: -1.623503, T: 8320, Avg. loss: 0.538273
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 5.32, NNZs: 7, Bias: -1.052405, T: 8640, Avg. loss: 0.487492
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 4.69, NNZs: 7, Bias: 0.150410, T: 8960, Avg. loss: 0.458757
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 4.89, NNZs: 7, Bias: -1.795815, T: 9280, Avg. loss: 0.469773
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 4.65, NNZs: 7, Bias: -2.067461, T: 9600, Avg. loss: 0.468203
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 4.85, NNZs: 7, Bias: -0.139834, T: 9920, Avg. loss: 0.454499
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 4.30, NNZs: 7, Bias: 0.378719, T: 10240, Avg. loss: 0.512806
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 3.62, NNZs: 7, Bias: -1.035789, T: 10560, Avg. loss: 0.445088
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 3.81, NNZs: 7, Bias: 0.150791, T: 10880, Avg. loss: 0.451232
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 4.72, NNZs: 7, Bias: 0.186991, T: 11200, Avg. loss: 0.426671
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 3.00, NNZs: 7, Bias: -1.689610, T: 11520, Avg. loss: 0.420412
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 5.07, NNZs: 7, Bias: -0.549779, T: 11840, Avg. loss: 0.403694
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 3.91, NNZs: 7, Bias: 0.174458, T: 12160, Avg. loss: 0.455658
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 2.98, NNZs: 7, Bias: 0.869620, T: 12480, Avg. loss: 0.420642
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 3.00, NNZs: 7, Bias: 0.041999, T: 12800, Avg. loss: 0.427353
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 3.90, NNZs: 7, Bias: -0.278503, T: 13120, Avg. loss: 0.402830
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 3.80, NNZs: 7, Bias: 0.251803, T: 13440, Avg. loss: 0.400605
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 3.36, NNZs: 7, Bias: -0.986695, T: 13760, Avg. loss: 0.397030
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 3.38, NNZs: 7, Bias: -0.746891, T: 14080, Avg. loss: 0.402955
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 3.53, NNZs: 7, Bias: 0.269443, T: 14400, Avg. loss: 0.396210
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 3.67, NNZs: 7, Bias: -0.310250, T: 14720, Avg. loss: 0.401490
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 4.19, NNZs: 7, Bias: -0.032157, T: 15040, Avg. loss: 0.400041
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 2.80, NNZs: 7, Bias: -0.138611, T: 15360, Avg. loss: 0.392028
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 4.04, NNZs: 7, Bias: 0.853475, T: 15680, Avg. loss: 0.364637
# Total training time: 0.00 seconds.
# -- Epoch 50
# Norm: 3.54, NNZs: 7, Bias: -1.137795, T: 16000, Avg. loss: 0.403069
# Total training time: 0.00 seconds.
# -- Epoch 51
# Norm: 2.67, NNZs: 7, Bias: -1.450652, T: 16320, Avg. loss: 0.378482
# Total training time: 0.00 seconds.
# -- Epoch 52
# Norm: 3.27, NNZs: 7, Bias: 0.653164, T: 16640, Avg. loss: 0.382733
# Total training time: 0.00 seconds.
# -- Epoch 53
# Norm: 3.44, NNZs: 7, Bias: -1.539852, T: 16960, Avg. loss: 0.376496
# Total training time: 0.00 seconds.
# -- Epoch 54
# Norm: 2.78, NNZs: 7, Bias: -1.064328, T: 17280, Avg. loss: 0.380166
# Total training time: 0.00 seconds.
# Convergence after 54 epochs took 0.00 seconds
# SGDClassifier(loss='log_loss', random_state=42, tol=0.0001, verbose=1)

# %%
# Veri setinin üzerinden 54 kere geçtikten sonra modelin ağırlıklarını ve bias'ını yazdırıyoruz.
print(f"Son Ağırlıklar (w): {sgd_model.coef_}")
print(f"\nSon Bias (b): {sgd_model.intercept_} \n")


importance_df = pd.DataFrame({"Özellik": X.columns,"Katsayı": model.coef_[0]}) # Önem sırasını yazdırabilmek için Özellik isimleri ve önem katsayılarını içeren bir DataFrame oluşturuyoruz.

# Katsayının mutlak değeriyle önem sıralaması yapıyoruz.
importance_df["Mutlak Katsayı"] = importance_df["Katsayı"].abs()
importance_df = importance_df.sort_values(by="Mutlak Katsayı", ascending=False)

print("Önem sırasına göre değişkenlerin katsayıları:")
print(importance_df[["Özellik", "Katsayı"]])
# Özelliklerin önem sırasını yazdırıyoruz.
# Out:
# Son Ağırlıklar (w): [[ 1.05759264  0.20564499  0.66702309  0.77903064 -0.3100472   2.25379537
#    0.58811616]]
#
# Son Bias (b): [-1.06432791]
#
# Önem sırasına göre değişkenlerin katsayıları:
#              Özellik   Katsayı
# 5               CGPA  1.777295
# 0          GRE Score  0.729352
# 3                SOP  0.420920
# 6           Research  0.411233
# 1        TOEFL Score  0.350700
# 2  University Rating  0.309486
# 4               LOR   0.253028

# %%
y = df["Chance of Admit Binary2"] # 0.70 eşik değeri ile ikili sınıflandırma
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42) # Veri setini eğitim ve test setlerine ayırıyoruz.

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Modeli 0.70 eşik değeri ile eğitim verisi ile eğitiyoruz.

y_pred = model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)
# Confusion matrix'i yazdırıyoruz.

accuracy = accuracy_score(y_test, y_pred)
print(f"Model Doğruluk Oranı: {accuracy:.2f}")
print("\nSınıflandırma Raporu:")
print(classification_report(y_test, y_pred))
# Modelin doğruluk oranını ve sınıflandırma raporunu yazdırıyoruz.

# Aynı adımları 0.70 eşik değeri için yapıyoruz.
# Out:
# Confusion Matrix:
# [[29  3]
#  [ 5 43]]
# Model Doğruluk Oranı: 0.90
#
# Sınıflandırma Raporu:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        32
#            1       0.93      0.90      0.91        48
#
#     accuracy                           0.90        80
#    macro avg       0.89      0.90      0.90        80
# weighted avg       0.90      0.90      0.90        80

# %%
y = df["Chance of Admit Binary3"] # 0.80 ve üzeri kabul oranı için ikili sınıflandırma
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42) # Veri setini eğitim ve test setlerine ayırıyoruz.

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Modeli 0.80 eşik değeri ile eğitim verisi ile eğitiyoruz.

y_pred = model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix) # Confusion matrix'i yazdırıyoruz.

accuracy = accuracy_score(y_test, y_pred)
print(f"Model Doğruluk Oranı: {accuracy:.2f}")
print("\nSınıflandırma Raporu:")
print(classification_report(y_test, y_pred))
# Modelin doğruluk oranını ve sınıflandırma raporunu yazdırıyoruz.

# Aynı adımları 0.80 eşik değeri için yapıyoruz.
# Out:
# Confusion Matrix:
# [[49  2]
#  [ 3 26]]
# Model Doğruluk Oranı: 0.94
#
# Sınıflandırma Raporu:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        51
#            1       0.93      0.90      0.91        29
#
#     accuracy                           0.94        80
#    macro avg       0.94      0.93      0.93        80
# weighted avg       0.94      0.94      0.94        80

# %% [markdown]
# Modellerimize baktığımızda genel olarak iyi sonuçlar aldığımızı görebiliriz. En iyi sonuç 0.80 eşik değeri ile %94 accuracy puanı ile elde edilmiştir. Bu sebeple Logistic regression için tercih edilen eşik değeri 0.80'dir.

# %% [markdown]
# Modelin geliştirilmesi için farklı yöntemler deneyebiliriz. Örneğin, modelin hiperparametrelerini en iyi halinde ayarlamak için GridSearchCV veya RandomizedSearchCV gibi yöntemler kullanabiliriz.
#
# Ayrıca, modelin performansını artırmak için daha karmaşık modeller deneyebiliriz.
# Örneğin, karar ağaçları (Decision Tree), rastgele ormanlar (Random Forest) veya destek vektör makineleri (Support Vector Machine (SVM)) gibi daha karmaşık algoritmalar kullanılabilir.
# Bu tarz modelleri kullandıktan sonra Ensemble öğrenme metodu ile hepsinin karışımını kullanarak daha sağlıklı tahminler yapılabilir.
#
# Bunun yanı sıra, modelin performansını artırmak için daha fazla veri toplamak veya veri ön işleme adımlarını iyileştirmek de faydalı olabilir.
# Özellikle özellik mühendisliği yapmak gibi adımlar modelin başarısını artırabilir.
#
# Tek bir eğitim‑test bölmesi yerine, k‑fold cross‑validation uygulayarak modelin farklı veri dilimlerinde ne kadar istikrarlı performans gösterdiğini ölçebilir, aşırı öğrenmeyi (overfitting) tespit edebiliriz.
